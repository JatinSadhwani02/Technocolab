# %%
import pandas as pd

# %%
d5 = pd.DataFrame({'ID':[1,2,3,4,5],'Colors':['Red','Blue','Green','Yellow','Pink']})
d6 = pd.DataFrame({'IDs':[6,7,8,9,10],'Colorses':['Wheat','Aqua','Skyblue','White','Black']})

# %%
display(d5,d6)
# Out:
#    ID  Colors
# 0   1     Red
# 1   2    Blue
# 2   3   Green
# 3   4  Yellow
# 4   5    Pink
#    IDs Colorses
# 0    6    Wheat
# 1    7     Aqua
# 2    8  Skyblue
# 3    9    White
# 4   10    Black

# %%
d5.join(d6)
# Out:
#    ID  Colors  IDs Colorses
# 0   1     Red    6    Wheat
# 1   2    Blue    7     Aqua
# 2   3   Green    8  Skyblue
# 3   4  Yellow    9    White
# 4   5    Pink   10    Black

# %%
d5.join(d6)
# Out:
#    ID  Colors  IDs Colorses
# 0   1     Red    6    Wheat
# 1   2    Blue    7     Aqua
# 2   3   Green    8  Skyblue
# 3   4  Yellow    9    White
# 4   5    Pink   10    Black

# %%
d7 = pd.DataFrame({'ID':[1,2,3,4,5],'Colors':['Red','Blue','Green','Yellow','Pink']})
d8 = pd.DataFrame({'ID':[6,7,8,9,10],'Colors':['Wheat','Aqua','Skyblue','White','Black']})

# %%
d7.append(d8,ignore_index=True)
# Out:
#    ID   Colors
# 0   1      Red
# 1   2     Blue
# 2   3    Green
# 3   4   Yellow
# 4   5     Pink
# 5   6    Wheat
# 6   7     Aqua
# 7   8  Skyblue
# 8   9    White
# 9  10    Black

# %%
rd = pd.read_csv('bestsellers with categories.csv',nrows=10)
rd
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1     Adult Coloring Book: Stress Relieving Patterns
# 2            12 Rules for Life: An Antidote to Chaos
# 3      A Higher Loyalty: Truth, Lies, and Leadership
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
# 6  A Game of Thrones / A Clash of Kings / A Storm...
# 7                     A Gentleman in Moscow: A Novel
# 8      A Higher Loyalty: Truth, Lies, and Leadership
# 9                          A Man Called Ove: A Novel
#
#                      Author  User Rating  Reviews  Price    Year        Genre
# 0                  JJ Smith          4.7  17350.0      8  2016.0  Non Fiction
# 1                       NaN          4.6   2052.0     22  2011.0      Fiction
# 2        Jordan B. Peterson          4.7  18979.0     15     NaN      Fiction
# ...

# %%
rd.pivot_table(columns='Name')
# Out:
# Name         10-Day Green Smoothie Cleanse  \
# Price                                  8.0
# Reviews                            17350.0
# User Rating                            4.7
# Year                                2016.0
#
# Name         12 Rules for Life: An Antidote to Chaos  \
# Price                                           15.0
# Reviews                                      18979.0
# User Rating                                      4.7
# Year                                             NaN
#
# Name         5,000 Awesome Facts (About Everything!) (National Geographic Kids)  \
# Price                                                     12.0
# Reviews                                                    NaN
# User Rating                                                4.8
# Year                                                    2019.0
#
# Name         A Dance with Dragons (A Song of Ice and Fire)  \
# Price                                                 11.0
# ...

# %%
pd.melt(rd)
# Out:
#        variable                                              value
# 0          Name                      10-Day Green Smoothie Cleanse
# 1          Name     Adult Coloring Book: Stress Relieving Patterns
# 2          Name            12 Rules for Life: An Antidote to Chaos
# 3          Name      A Higher Loyalty: Truth, Lies, and Leadership
# 4          Name  5,000 Awesome Facts (About Everything!) (Natio...
# 5          Name      A Dance with Dragons (A Song of Ice and Fire)
# 6          Name  A Game of Thrones / A Clash of Kings / A Storm...
# 7          Name                     A Gentleman in Moscow: A Novel
# 8          Name      A Higher Loyalty: Truth, Lies, and Leadership
# 9          Name                          A Man Called Ove: A Novel
# 10       Author                                           JJ Smith
# 11       Author                                                NaN
# 12       Author                                 Jordan B. Peterson
# ...

# %%
pd.melt(rd,id_vars=['Year'],value_vars=['Name'],var_name=['Category'])
# Out:
#      Year Category                                              value
# 0  2016.0     Name                      10-Day Green Smoothie Cleanse
# 1  2011.0     Name     Adult Coloring Book: Stress Relieving Patterns
# 2     NaN     Name            12 Rules for Life: An Antidote to Chaos
# 3  2017.0     Name      A Higher Loyalty: Truth, Lies, and Leadership
# 4  2019.0     Name  5,000 Awesome Facts (About Everything!) (Natio...
# 5     NaN     Name      A Dance with Dragons (A Song of Ice and Fire)
# 6  2014.0     Name  A Game of Thrones / A Clash of Kings / A Storm...
# 7  2017.0     Name                     A Gentleman in Moscow: A Novel
# 8  2018.0     Name      A Higher Loyalty: Truth, Lies, and Leadership
# 9  2016.0     Name                          A Man Called Ove: A Novel
